# %%
import pymongo
import pprint

uri = ("mongodb://analytics:analytics-password@mflix-shard-00-00-qxfdz.mongodb.net:27017,mflix-shard-00-01-qxfdz.mongodb.net:27017,mflix-shard-00-02-qxfdz.mongodb.net:27017/test?ssl=true&replicaSet=mflix-shard-0&authSource=admin&retryWrites=true")
mc = pymongo.MongoClient(uri)
mflix = mc.mflix

# %%
titanic = mflix.movies.find_one({'title': 'Titanic'})

pprint.pprint(titanic)
# Out:
# {'_id': ObjectId('573a1394f29313caabcdf639'),
#  'awards': 'Won 1 Oscar. Another 2 nominations.',
#  'cast': ['Clifton Webb', 'Barbara Stanwyck', 'Robert Wagner', 'Audrey Dalton'],
#  'comments': [{'_id': '573a1394f29313caabcdf639-Robert Baratheon-596239972.0',
#                'date': datetime.datetime(1988, 11, 22, 17, 12, 52),
#                'email': 'mark_addy@gameofthron.es',
#                'movie_id': ObjectId('573a1394f29313caabcdf639'),
#                'name': 'Robert Baratheon',
#                'text': 'Voluptatem velit ratione aperiam earum. Aliquam iusto '
#                        'praesentium incidunt tenetur quod amet. Facere natus '
#                        'dolore nemo earum nesciunt velit.'}],
#  'countries': ['USA'],
#  'directors': ['Jean Negulesco'],
#  'fullplot': 'Unhappily married and uncomfortable with life among the British '
#              'upper crust, Julia Sturges takes her two children and boards the '
# ...

# %%
titanic["tomatoes"]
# Out:
# {'viewer': {'rating': 3.6, 'numReviews': 86400, 'meter': 65},
#  'dvd': datetime.datetime(2003, 9, 2, 0, 0),
#  'rotten': 1,
#  'lastUpdated': datetime.datetime(2015, 9, 10, 19, 15, 34),
#  'critic': {'rating': 6.7, 'numReviews': 9, 'meter': 89},
#  'production': '20th Century Fox',
#  'fresh': 8}

# %%
titanic["tomatoes"]["viewer"]
# Out:
# {'rating': 3.6, 'numReviews': 86400, 'meter': 65}

# %%
rating = titanic["tomatoes"]["viewer"]["rating"]
rating
# Out:
# 3.6

# %%
cursor = mflix.movies.find({'tomatoes.viewer.rating': rating})
for movie in cursor:
    pprint.pprint(movie['title'])
# Out:
# 'Life of an American Fireman'
# "The '?' Motorist"
# 'Dream of a Rarebit Fiend'
# 'A Corner in Wheat'
# 'The Lonely Villa'
# 'The Sealed Room'
# 'Those Awful Hats'
# 'Juve Against Fantomas'
# 'The Dead Man Who Killed'
# 'Fantomas Against Fantomas'
# 'The Captive'
# 'The Champion'
# 'Carmen'
# 'Fatty and Mabel Adrift'
# 'The Fireman'
# 'The Floorwalker'
# 'Judex'
# 'One A.M.'
# 'The Pawnshop'
# 'Amarilly of Clothes-Line Alley'
# 'The Blue Bird'
# 'Different from the Others'
# 'Back Stage'
# "I Don't Want to Be a Man"
# 'Sunnyside'
# 'The Flapper'
# 'The Golem'
# 'Way Down East'
# 'The Paleface'
# 'Robin Hood'
# 'Sherlock Holmes'
# 'The Smiling Madame Beudet'
# 'The Balloonatic'
# 'The Hunchback of Notre Dame'
# 'Scaramouche'
# 'Three Ages'
# 'Michael'
# 'The Circle'
# 'Clash of the Wolves'
# 'Go West'
# 'The Wizard of Oz'
# 'Beau Geste'
# 'The Bells'
# 'Don Juan'
# "For Heaven's Sake"
# 'The Great Gatsby'
# 'The Great K & A Train Robbery'
# 'The Lodger'
# 'Old Ironsides'
# ...

# %%
cursor = mflix.movies.find({'tomatoes.viewer.rating': rating})
cursor.sort('tomatoes.lastUpdated', pymongo.ASCENDING)
for movie in cursor:
    pprint.pprint( "Title: {0}; LastUdpated: {1}".format( movie['title'], movie['tomatoes']['lastUpdated']))
# Out:
# 'Title: Rampage; LastUdpated: 2012-09-30 00:00:00'
# 'Title: The Suspect; LastUdpated: 2014-04-15 07:04:25'
# 'Title: Dickson Greeting; LastUdpated: 2014-11-23 05:39:46'
# 'Title: Film Noir: Bringing Darkness to Light; LastUdpated: 2014-11-27 09:15:00'
# 'Title: Restart; LastUdpated: 2014-12-07 07:07:08'
# 'Title: We Can Be Heroes; LastUdpated: 2014-12-08 23:26:30'
# 'Title: Ol�!; LastUdpated: 2014-12-10 22:51:38'
# 'Title: Ye ban ge sheng; LastUdpated: 2015-01-02 18:52:16'
# 'Title: Sel8nne; LastUdpated: 2015-01-07 18:10:08'
# "Title: L'ennui; LastUdpated: 2015-01-08 03:16:26"
# 'Title: The Lighthouse; LastUdpated: 2015-01-08 03:16:26'
# 'Title: The Lighthouse; LastUdpated: 2015-01-08 03:16:26'
# 'Title: The Lighthouse; LastUdpated: 2015-01-08 03:16:26'
# 'Title: King Lear; LastUdpated: 2015-01-09 04:35:56'
# 'Title: One; LastUdpated: 2015-01-09 14:06:42'
# 'Title: The Illumination; LastUdpated: 2015-01-10 09:12:19'
# 'Title: No Love for Johnnie; LastUdpated: 2015-01-10 20:22:45'
# ...
